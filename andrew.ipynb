# %%
import pandas as pd

# %%
df = pd.read_csv('tracks_enriched.csv', sep='\t')
df
# Out:
#                         song_id                album_id  track_number  \
# 0        3e9HZxeyfWwjeyPAMmWSSQ  2fYhqwDWXjbpjaIJPEfKFw            11
# 1        5p7ujcrUXASCNwRaWNHR1C  0zzrCTzvL4ZmR42xF46Afm             1
# 2        2xLMifQCjDGFmkHkpNLD9h  41GuZcammIkupMPKH2OJ6I             3
# 3        2xLMifQCjDGFmkHkpNLD9h  41GuZcammIkupMPKH2OJ6I             3
# 4        2xLMifQCjDGFmkHkpNLD9h  41GuZcammIkupMPKH2OJ6I             3
# ...                         ...                     ...           ...
# 1986380  30342v7I9sUoNC0Djnu1mW  1bZHbHtUvjGqUOKNla4lo0            25
# 1986381  5rkgbGIOTBGlKTAawWb06X  3GmCXW10kLxmZrEY0JpRlw             9
# 1986382  5rkgbGIOTBGlKTAawWb06X  3GmCXW10kLxmZrEY0JpRlw             9
# 1986383  2MVPsa4S4r7Ii5lMh85E03  0UiVuqXa69zXqql0GoXH2h            22
# 1986384  7wGbzk3aeGSpnsK2AQ7vzA  3pBArpt3QcnvVj58hl6Ghe             7
#
#         release_date_x release_date_precision_x  \
# 0           2019-02-08                      day
# 1           2018-10-04                      day
# 2           2018-08-03                      day
# 3           2018-08-03                      day
# 4           2018-08-03                      day
# ...                ...                      ...
# 1986380     2000-01-01                      day
# 1986381     1988-03-07                      day
# 1986382     1988-03-07                      day
# 1986383     2013-01-31                      day
# 1986384     2012-05-31                      day
#
#                                             name     billboard  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                     ASTROWORLD    ASTROWORLD
# 3                                     ASTROWORLD    ASTROWORLD
# 4                                     ASTROWORLD    ASTROWORLD
# ...                                          ...           ...
# 1986380                                      NaN           NaN
# 1986381  Past Masters (Vols. 1 & 2 / Remastered)  Past Masters
# 1986382  Past Masters (Vols. 1 & 2 / Remastered)  Past Masters
# 1986383                                      NaN           NaN
# 1986384                                      NaN           NaN
#
#                                             artists  popularity  total_tracks  \
# 0                                               NaN         NaN           NaN
# 1                                               NaN         NaN           NaN
# 2        {'0Y5tJX1MQlPlqiwlOH1tJY': 'Travis Scott'}        91.0          17.0
# 3        {'0Y5tJX1MQlPlqiwlOH1tJY': 'Travis Scott'}        91.0          17.0
# 4        {'0Y5tJX1MQlPlqiwlOH1tJY': 'Travis Scott'}        91.0          17.0
# ...                                             ...         ...           ...
# 1986380                                         NaN         NaN           NaN
# 1986381   {'3WrFJ7ztbogyGnTHbHJFl2': 'The Beatles'}        61.0          33.0
# 1986382   {'3WrFJ7ztbogyGnTHbHJFl2': 'The Beatles'}        61.0          33.0
# 1986383                                         NaN         NaN           NaN
# 1986384                                         NaN         NaN           NaN
#
#          ... year_end_score is_pop    year rank_score  peak_position  \
# 0        ...            NaN    NaN     NaN        NaN            NaN
# 1        ...            NaN    NaN     NaN        NaN            NaN
# 2        ...         4210.0   True  2018.0      195.0          200.0
# 3        ...         4210.0   True  2018.0      195.0          200.0
# 4        ...         4210.0   True  2018.0      193.0          200.0
# ...      ...            ...    ...     ...        ...            ...
# 1986380  ...            NaN    NaN     NaN        NaN            NaN
# 1986381  ...           73.0  False  2010.0       47.0           47.0
# 1986382  ...           73.0  False  2010.0       24.0           24.0
# 1986383  ...            NaN    NaN     NaN        NaN            NaN
# 1986384  ...            NaN    NaN     NaN        NaN            NaN
#
#          week_count        date               artist_id release_date_y  \
# 0               NaN         NaN                     NaN            NaN
# 1               NaN         NaN                     NaN            NaN
# 2              20.0  2018-12-29  0Y5tJX1MQlPlqiwlOH1tJY     2018-08-03
# 3              19.0  2018-12-22  0Y5tJX1MQlPlqiwlOH1tJY     2018-08-03
# 4              18.0  2018-12-15  0Y5tJX1MQlPlqiwlOH1tJY     2018-08-03
# ...             ...         ...                     ...            ...
# 1986380         NaN         NaN                     NaN            NaN
# 1986381         2.0  2010-01-09  3WrFJ7ztbogyGnTHbHJFl2     1988-03-07
# 1986382         0.0  2010-01-02  3WrFJ7ztbogyGnTHbHJFl2     1988-03-07
# 1986383         NaN         NaN                     NaN            NaN
# 1986384         NaN         NaN                     NaN            NaN
#
#         release_date_precision_y
# 0                            NaN
# 1                            NaN
# 2                            day
# 3                            day
# 4                            day
# ...                          ...
# 1986380                      NaN
# 1986381                      day
# 1986382                      day
# 1986383                      NaN
# 1986384                      NaN
#
# [1986385 rows x 22 columns]

# %%
# how many nan's in each column
nan_counts = df.isna().sum()
nan_counts
# Out:
# song_id                        0
# album_id                       0
# track_number                   0
# release_date_x                 0
# release_date_precision_x       0
# name                        9105
# billboard                   9105
# artists                     9105
# popularity                  9105
# total_tracks                9105
# album_type                  9105
# image_url                   9105
# year_end_score              9112
# is_pop                      9112
# year                        9112
# rank_score                  9112
# peak_position               9112
# week_count                  9112
# date                        9112
# artist_id                   9105
# release_date_y              9105
# release_date_precision_y    9105
# dtype: int64

# %%
df2 = pd.read_csv('artists_enriched.csv', sep='\t')
df2
# Out:
# /var/folders/nw/0j298g817b92m2qlhw1_fwnr0000gn/T/ipykernel_42300/871867837.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('artists_enriched.csv', sep='\t')
#                       artist_id           name   followers  popularity  \
# 0        66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96
# 1        66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96
# 2        66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96
# 3        66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96
# 4        66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96
# ...                         ...            ...         ...         ...
# 6590749  45d3pteh2TnzUMMl27J4MY   Tommy Morgan        78.0          15
# 6590750  45d3pteh2TnzUMMl27J4MY   Tommy Morgan        78.0          15
# 6590751  45d3pteh2TnzUMMl27J4MY   Tommy Morgan        78.0          15
# 6590752  45d3pteh2TnzUMMl27J4MY   Tommy Morgan        78.0          15
# 6590753  45d3pteh2TnzUMMl27J4MY   Tommy Morgan        78.0          15
#
#         artist_type main_genre                                 genres  \
# 0            singer  dance pop  ['dance pop', 'pop', 'post-teen pop']
# 1            singer  dance pop  ['dance pop', 'pop', 'post-teen pop']
# 2            singer  dance pop  ['dance pop', 'pop', 'post-teen pop']
# 3            singer  dance pop  ['dance pop', 'pop', 'post-teen pop']
# 4            singer  dance pop  ['dance pop', 'pop', 'post-teen pop']
# ...             ...        ...                                    ...
# 6590749      singer          -                                     []
# 6590750      singer          -                                     []
# 6590751      singer          -                                     []
# 6590752      singer          -                                     []
# 6590753      singer          -                                     []
#
#                                                  image_url  year_end_score  \
# 0        https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...         26508.0
# 1        https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...         26508.0
# 2        https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...         26508.0
# 3        https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...         26508.0
# 4        https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...         26508.0
# ...                                                    ...             ...
# 6590749  https://i.scdn.co/image/1c5cb45ccb80438b72a98a...          1193.0
# 6590750  https://i.scdn.co/image/1c5cb45ccb80438b72a98a...          1193.0
# 6590751  https://i.scdn.co/image/1c5cb45ccb80438b72a98a...          1193.0
# 6590752  https://i.scdn.co/image/1c5cb45ccb80438b72a98a...          1193.0
# 6590753  https://i.scdn.co/image/1c5cb45ccb80438b72a98a...          1193.0
#
#         is_pop    year  rank_score  peak_position  weeks_on_chart        week
# 0         True  2018.0       457.0          665.0           171.0  2018-12-29
# 1         True  2018.0       448.0          681.0           189.0  2018-12-22
# 2         True  2018.0       486.0          681.0           184.0  2018-12-15
# 3         True  2018.0       462.0          680.0           179.0  2018-12-08
# 4         True  2018.0       486.0          680.0           174.0  2018-12-01
# ...        ...     ...         ...            ...             ...         ...
# 6590749   True  1975.0        52.0           52.0             5.0  1975-06-14
# 6590750   True  1975.0        41.0           41.0             4.0  1975-06-07
# 6590751   True  1975.0        30.0           30.0             3.0  1975-05-31
# 6590752   True  1975.0        19.0           19.0             2.0  1975-05-24
# 6590753   True  1975.0         8.0            8.0             0.0  1975-05-17
#
# [6590754 rows x 15 columns]

# %%
df3 = pd.read_csv('songs_popularity.csv', sep='\t')
df3
# Out:
# /var/folders/nw/0j298g817b92m2qlhw1_fwnr0000gn/T/ipykernel_42300/3624914712.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('songs_popularity.csv', sep='\t')
#                        song_id      song_name  \
# 0       3e9HZxeyfWwjeyPAMmWSSQ  thank u, next
# 1       3e9HZxeyfWwjeyPAMmWSSQ  thank u, next
# 2       3e9HZxeyfWwjeyPAMmWSSQ  thank u, next
# 3       3e9HZxeyfWwjeyPAMmWSSQ  thank u, next
# 4       3e9HZxeyfWwjeyPAMmWSSQ  thank u, next
# ...                        ...            ...
# 339339  2H9CKpZiLDF223BbwehpDF      Hush Hush
# 339340  2H9CKpZiLDF223BbwehpDF      Hush Hush
# 339341  2H9CKpZiLDF223BbwehpDF      Hush Hush
# 339342  2H9CKpZiLDF223BbwehpDF      Hush Hush
# 339343  2H9CKpZiLDF223BbwehpDF      Hush Hush
#
#                                                 billboard  \
# 0                      ('Thank U, Next', 'Ariana Grande')
# 1                      ('Thank U, Next', 'Ariana Grande')
# 2                      ('Thank U, Next', 'Ariana Grande')
# 3                      ('Thank U, Next', 'Ariana Grande')
# 4                      ('Thank U, Next', 'Ariana Grande')
# ...                                                   ...
# 339339  ('Hush Hush', 'The Pussycat Dolls Featuring Ni...
# 339340  ('Hush Hush', 'The Pussycat Dolls Featuring Ni...
# 339341  ('Hush Hush', 'The Pussycat Dolls Featuring Ni...
# 339342  ('Hush Hush', 'The Pussycat Dolls Featuring Ni...
# 339343  ('Hush Hush', 'The Pussycat Dolls Featuring Ni...
#
#                                                  artists  popularity  \
# 0            {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86
# 1            {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86
# 2            {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86
# 3            {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86
# 4            {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86
# ...                                                  ...         ...
# 339339  {'6wPhSqRtPu1UhRCDX5yaDJ': 'The Pussycat Dolls'}          57
# 339340  {'6wPhSqRtPu1UhRCDX5yaDJ': 'The Pussycat Dolls'}          57
# 339341  {'6wPhSqRtPu1UhRCDX5yaDJ': 'The Pussycat Dolls'}          57
# 339342  {'6wPhSqRtPu1UhRCDX5yaDJ': 'The Pussycat Dolls'}          57
# 339343  {'6wPhSqRtPu1UhRCDX5yaDJ': 'The Pussycat Dolls'}          57
#
#         explicit song_type  duration_ms  key  mode  ...  valence    tempo  \
# 0           True      Solo       207320    1     1  ...    0.412  106.966
# 1           True      Solo       207320    1     1  ...    0.412  106.966
# 2           True      Solo       207320    1     1  ...    0.412  106.966
# 3           True      Solo       207320    1     1  ...    0.412  106.966
# 4           True      Solo       207320    1     1  ...    0.412  106.966
# ...          ...       ...          ...  ...   ...  ...      ...      ...
# 339339     False      Solo       252093   10     0  ...    0.664  129.334
# 339340     False      Solo       252093   10     0  ...    0.664  129.334
# 339341     False      Solo       252093   10     0  ...    0.664  129.334
# 339342     False      Solo       252093   10     0  ...    0.664  129.334
# 339343     False      Solo       252093   10     0  ...    0.664  129.334
#
#                                                    lyrics  year_end_score  \
# 0       ['[Verse 1]\nThought I\'d end up with Sean\nBu...           728.0
# 1       ['[Verse 1]\nThought I\'d end up with Sean\nBu...           728.0
# 2       ['[Verse 1]\nThought I\'d end up with Sean\nBu...           728.0
# 3       ['[Verse 1]\nThought I\'d end up with Sean\nBu...           728.0
# 4       ['[Verse 1]\nThought I\'d end up with Sean\nBu...           728.0
# ...                                                   ...             ...
# 339339                                                NaN           273.0
# 339340                                                NaN           273.0
# 339341                                                NaN           273.0
# 339342                                                NaN           273.0
# 339343                                                NaN           273.0
#
#         is_pop    year  rank_score  peak_position  weeks_on_chart        week
# 0         True  2018.0       100.0          100.0             7.0  2018-12-29
# 1         True  2018.0       100.0          100.0             6.0  2018-12-22
# 2         True  2018.0       100.0          100.0             5.0  2018-12-15
# 3         True  2018.0        99.0          100.0             4.0  2018-12-08
# 4         True  2018.0       100.0          100.0             3.0  2018-12-01
# ...        ...     ...         ...            ...             ...         ...
# 339339   False  2009.0        26.0           28.0             5.0  2009-08-08
# 339340   False  2009.0        18.0           28.0             4.0  2009-08-01
# 339341   False  2009.0        16.0           28.0             3.0  2009-07-25
# 339342   False  2009.0        28.0           28.0             2.0  2009-07-18
# 339343   False  2009.0         5.0            5.0             0.0  2009-05-30
#
# [339344 rows x 28 columns]

# %%
artist_year_scores = df2.groupby(['name', 'year'])['year_end_score'].sum().reset_index()
artist_year_scores.sort_values(by = 'year')
# Out:
#                           name    year  year_end_score
# 30299              The Animals  1964.0       1023891.0
# 10057            Elvis Presley  1964.0      14781126.0
# 11315           Frank Fontaine  1964.0         13536.0
# 820                    Al Hirt  1964.0       3839165.0
# 15821  John Fitzgerald Kennedy  1964.0         13869.0
# ...                        ...     ...             ...
# 20507            Mayday Parade  2018.0          1552.0
# 33436              The Wombats  2018.0            22.0
# 20583                Meek Mill  2018.0        867510.0
# 19985             Mariah Carey  2018.0       2844055.0
# 8575              Denzel Curry  2018.0          2804.0
#
# [36601 rows x 3 columns]

# %%
# drop these features from df3 year_end_score	is_pop	year	rank_score	peak_position	weeks_on_chart	week
df4 = df3[['song_id','song_name', 'popularity','danceability','energy','valence','acousticness','speechiness']]
df4
# Out:
#                        song_id  popularity  danceability  energy  valence  \
# 0       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# 1       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# 2       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# 3       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# 4       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# ...                        ...         ...           ...     ...      ...
# 339339  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
# 339340  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
# 339341  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
# 339342  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
# 339343  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
#
#         acousticness  speechiness
# 0              0.229       0.0658
# 1              0.229       0.0658
# 2              0.229       0.0658
# 3              0.229       0.0658
# 4              0.229       0.0658
# ...              ...          ...
# 339339         0.105       0.0663
# 339340         0.105       0.0663
# 339341         0.105       0.0663
# 339342         0.105       0.0663
# 339343         0.105       0.0663
#
# [339344 rows x 7 columns]

# %%
# keep only unique song_ids
df4_unique = df4.drop_duplicates(subset=['song_id'])
df4_unique
# Out:
#                        song_id  popularity  danceability  energy  valence  \
# 0       3e9HZxeyfWwjeyPAMmWSSQ          86         0.717   0.653    0.412
# 7       5p7ujcrUXASCNwRaWNHR1C          87         0.752   0.488    0.533
# 18      2xLMifQCjDGFmkHkpNLD9h          85         0.834   0.730    0.446
# 38      3KkXRkHbMCARz0aVfEt68P          92         0.760   0.479    0.913
# 47      1rqqCSm0Qe4I9rUvWncaom          86         0.579   0.904    0.681
# ...                        ...         ...           ...     ...      ...
# 339311  4NnhLA66RRLXxKbiiscU9R          36         0.231   0.455    0.391
# 339322  2jHfXdCLibrI1J56LnUAZv           1         0.239   0.598    0.829
# 339324  6zqsyB7uIvWrL1iCJzpNrs          20         0.422   0.494    0.723
# 339331  5mz9pQZZXNpAw9CdQ7Bk8q           7         0.500   0.654    0.403
# 339335  2H9CKpZiLDF223BbwehpDF          57         0.609   0.790    0.664
#
#         acousticness  speechiness
# 0           0.229000       0.0658
# 7           0.297000       0.0705
# 18          0.005130       0.2220
# 38          0.556000       0.0466
# 47          0.193000       0.0618
# ...              ...          ...
# 339311      0.841000       0.0296
# 339322      0.195000       0.0416
# 339324      0.000942       0.0528
# 339331      0.619000       0.0394
# 339335      0.105000       0.0663
#
# [20405 rows x 7 columns]

# %%
# download df4unique as unique_songs.csv
df4_unique.to_csv('unique_songs.csv', sep=',', index=False)
